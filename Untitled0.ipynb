# %% [markdown]
# <a href="https://colab.research.google.com/github/sahana40/Learn-From-Home/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
activities = ['China','Germany','Italy','France']
sizes = [115,130,245,210]
cols = ['c','m','r','b']

plt.pie(slices,
        labels=activities,
        colors=cols,
        startangle=360,
        shadow=True,
        autopct='%1.1f%%')

plt.axis('equal')
plt.show()
